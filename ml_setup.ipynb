# %%
# ML Environment Setup
print("This notebook verifies that required Python packages are installed and runs a tiny sample.")
# Out:
# This notebook verifies that required Python packages are installed and runs a tiny sample.

# %%
import sys
# !{sys.executable} -m pip install numpy pandas scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.9 kB 2.6 MB/s eta 0:00:01
#      ---------------------------------------- 60.9/60.9 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached scipy-1.16.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    - -------------------------------------- 0.6/13.1 MB 12.9 MB/s eta 0:00:01
#    -- ------------------------------------- 0.8/13.1 MB 8.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/13.1 MB 7.7 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/13.1 MB 7.7 MB/s eta 0:00:02
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

print("numpy:", np.__version__)
print("pandas:", pd.__version__)

X = np.array([[1],[2],[3],[4]])
y = np.array([2,4,6,8])

model = LinearRegression().fit(X, y)

print("coef:", model.coef_, "intercept:", model.intercept_)
# Out:
# numpy: 2.3.5
# pandas: 2.3.3
# coef: [2.] intercept: 0.0

# %%
git add requirements-ml.txt ml_setup.ipynb
git commit -m "Add ML environment requirements and verification notebook"
git push origin main
# Out:
#   Cell In[15], line 1
#     git add requirements-ml.txt ml_setup.ipynb
#         ^
# SyntaxError: invalid syntax
